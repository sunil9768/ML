# %%
import numpy as np

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
#Read the train data
dataset_train=pd.read_csv('/home/sunil/Downloads/hacker earth compition/Dataset/train.csv')

# %%
dataset_train
# Out:
#                area_assesed   building_id damage_grade  district_id  \
# 0                      Both   24385bfd2a2      Grade 4           24
# 1                      Both   405d1bbebbf      Grade 2           44
# 2                      Both   351d9bc71f6      Grade 1           36
# 3          Building removed   2be3a971166      Grade 5           30
# 4                      Both   34c7d073ea6      Grade 3           36
# 5                  Exterior   1f54965821f      Grade 5           21
# 6                      Both   2beb42eaeee      Grade 2           30
# 7                      Both   25e8adfd09a      Grade 5           26
# 8                      Both   1e96b58fa58      Grade 1           21
# 9                      Both   392cbd772c9      Grade 3           39
# 10                 Exterior   35074b0c35f      Grade 5           36
# 11                     Both   1ee123fa622      Grade 4           21
# 12                     Both   107560bc53d      Grade 2           11
# ...

# %%
#store the damage_grade into another variable
A=dataset_train['damage_grade']

# %%
y_train=np_utils.to_categorical(A)
# Out:
# 0         Grade 4
# 1         Grade 2
# 2         Grade 1
# 3         Grade 5
# 4         Grade 3
# 5         Grade 5
# 6         Grade 2
# 7         Grade 5
# 8         Grade 1
# 9         Grade 3
# 10        Grade 5
# 11        Grade 4
# 12        Grade 2
# 13        Grade 5
# 14        Grade 2
# 15        Grade 5
# 16        Grade 4
# 17        Grade 3
# 18        Grade 4
# 19        Grade 3
# 20        Grade 4
# 21        Grade 4
# 22        Grade 4
# 23        Grade 5
# 24        Grade 4
# 25        Grade 3
# 26        Grade 5
# 27        Grade 5
# 28        Grade 5
# 29        Grade 5
#            ...
# 631731    Grade 3
# 631732    Grade 4
# 631733    Grade 4
# 631734    Grade 5
# 631735    Grade 5
# 631736    Grade 3
# 631737    Grade 5
# 631738    Grade 5
# 631739    Grade 2
# 631740    Grade 3
# 631741    Grade 3
# 631742    Grade 5
# 631743    Grade 5
# 631744    Grade 5
# 631745    Grade 5
# 631746    Grade 5
# 631747    Grade 2
# 631748    Grade 4
# 631749    Grade 5
# ...

# %%
#labelEncoder of A
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
A=le.fit_transform(A)

# %%
pd.DataFrame(A)
# Out:
#         0
# 0       3
# 1       1
# 2       0
# 3       4
# 4       2
# 5       4
# 6       1
# 7       4
# 8       0
# 9       2
# 10      4
# 11      3
# 12      1
# 13      4
# 14      1
# 15      4
# 16      3
# 17      2
# 18      3
# 19      2
# 20      3
# 21      3
# 22      3
# 23      4
# 24      3
# 25      2
# 26      4
# 27      4
# 28      4
# 29      4
# ...    ..
# 631731  2
# 631732  3
# 631733  3
# 631734  4
# 631735  4
# 631736  2
# 631737  4
# 631738  4
# 631739  1
# 631740  2
# 631741  2
# 631742  4
# 631743  4
# 631744  4
# 631745  4
# 631746  4
# 631747  1
# 631748  3
# 631749  4
# 631750  4
# 631751  4
# 631752  4
# 631753  3
# 631754  2
# 631755  0
# 631756  3
# 631757  4
# 631758  1
# 631759  3
# 631760  1
#
# [631761 rows x 1 columns]

# %%
# delete the Damage_grade from train_dataset
del dataset_train['damage_grade']

# %%
dataset_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 631761 entries, 0 to 631760
# Data columns (total 13 columns):
# area_assesed                             631761 non-null object
# building_id                              631761 non-null object
# district_id                              631761 non-null int64
# has_geotechnical_risk                    631761 non-null float64
# has_geotechnical_risk_fault_crack        631761 non-null int64
# has_geotechnical_risk_flood              631761 non-null int64
# has_geotechnical_risk_land_settlement    631761 non-null int64
# has_geotechnical_risk_landslide          631761 non-null int64
# has_geotechnical_risk_liquefaction       631761 non-null int64
# has_geotechnical_risk_other              631761 non-null int64
# has_geotechnical_risk_rock_fall          631761 non-null int64
# has_repair_started                       598344 non-null float64
# vdcmun_id                                631761 non-null int64
# ...

# %%
#Read the test data
dataset_test=pd.read_csv('/home/sunil/Downloads/hacker earth compition/Dataset/test.csv')

# %%
dataset_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421175 entries, 0 to 421174
# Data columns (total 13 columns):
# area_assesed                             421175 non-null object
# building_id                              421175 non-null object
# district_id                              421175 non-null int64
# has_geotechnical_risk                    421175 non-null float64
# has_geotechnical_risk_fault_crack        421175 non-null int64
# has_geotechnical_risk_flood              421175 non-null int64
# has_geotechnical_risk_land_settlement    421175 non-null int64
# has_geotechnical_risk_landslide          421175 non-null int64
# has_geotechnical_risk_liquefaction       421175 non-null int64
# has_geotechnical_risk_other              421175 non-null int64
# has_geotechnical_risk_rock_fall          421175 non-null int64
# has_repair_started                       399253 non-null float64
# vdcmun_id                                421175 non-null int64
# ...

# %%
#B=dataset_test["building_id"]

# %%
# combined the both data of train & test store the into another variable
All_data=[dataset_train,dataset_test]

# %%
 All_data1=pd.concat(All_data)

# %%
All_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1052936 entries, 0 to 421174
# Data columns (total 13 columns):
# area_assesed                             1052936 non-null object
# building_id                              1052936 non-null object
# district_id                              1052936 non-null int64
# has_geotechnical_risk                    1052936 non-null float64
# has_geotechnical_risk_fault_crack        1052936 non-null int64
# has_geotechnical_risk_flood              1052936 non-null int64
# has_geotechnical_risk_land_settlement    1052936 non-null int64
# has_geotechnical_risk_landslide          1052936 non-null int64
# has_geotechnical_risk_liquefaction       1052936 non-null int64
# has_geotechnical_risk_other              1052936 non-null int64
# has_geotechnical_risk_rock_fall          1052936 non-null int64
# has_repair_started                       997597 non-null float64
# vdcmun_id                                1052936 non-null int64
# ...

# %%
#filling the missing value of has_repair_started
means=All_data1["has_repair_started"].mean()
All_data1["has_repair_started"].fillna(means,inplace=True)
means
All_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1052936 entries, 0 to 421174
# Data columns (total 13 columns):
# area_assesed                             1052936 non-null object
# building_id                              1052936 non-null object
# district_id                              1052936 non-null int64
# has_geotechnical_risk                    1052936 non-null float64
# has_geotechnical_risk_fault_crack        1052936 non-null int64
# has_geotechnical_risk_flood              1052936 non-null int64
# has_geotechnical_risk_land_settlement    1052936 non-null int64
# has_geotechnical_risk_landslide          1052936 non-null int64
# has_geotechnical_risk_liquefaction       1052936 non-null int64
# has_geotechnical_risk_other              1052936 non-null int64
# has_geotechnical_risk_rock_fall          1052936 non-null int64
# has_repair_started                       1052936 non-null float64
# vdcmun_id                                1052936 non-null int64
# ...

# %%
b= All_data1['building_id']

# %%
del All_data1["building_id"]

# %%
# select the object Data
obj_df=All_data1.select_dtypes(include=['object'])
obj_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1052936 entries, 0 to 421174
# Data columns (total 1 columns):
# area_assesed    1052936 non-null object
# dtypes: object(1)
# memory usage: 16.1+ MB

# %%
#dummmies the object data
obj_df_dummies=pd.get_dummies(obj_df)

# %%
type(obj_df_dummies)
# Out:
# pandas.core.frame.DataFrame

# %%
del All_data1['area_assesed']

# %%
type(All_data1)
# Out:
# pandas.core.frame.DataFrame

# %%
All_data1=pd.concat([ All_data1,obj_df_dummies],axis=1)

# %%
All_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1052936 entries, 0 to 421174
# Data columns (total 16 columns):
# district_id                              1052936 non-null int64
# has_geotechnical_risk                    1052936 non-null float64
# has_geotechnical_risk_fault_crack        1052936 non-null int64
# has_geotechnical_risk_flood              1052936 non-null int64
# has_geotechnical_risk_land_settlement    1052936 non-null int64
# has_geotechnical_risk_landslide          1052936 non-null int64
# has_geotechnical_risk_liquefaction       1052936 non-null int64
# has_geotechnical_risk_other              1052936 non-null int64
# has_geotechnical_risk_rock_fall          1052936 non-null int64
# has_repair_started                       1052936 non-null float64
# vdcmun_id                                1052936 non-null int64
# area_assesed_Both                        1052936 non-null uint8
# area_assesed_Building removed            1052936 non-null uint8
# ...

# %%
#split data into train data
X_train=All_data1[0:631761]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 631761 entries, 0 to 631760
# Data columns (total 16 columns):
# district_id                              631761 non-null int64
# has_geotechnical_risk                    631761 non-null float64
# has_geotechnical_risk_fault_crack        631761 non-null int64
# has_geotechnical_risk_flood              631761 non-null int64
# has_geotechnical_risk_land_settlement    631761 non-null int64
# has_geotechnical_risk_landslide          631761 non-null int64
# has_geotechnical_risk_liquefaction       631761 non-null int64
# has_geotechnical_risk_other              631761 non-null int64
# has_geotechnical_risk_rock_fall          631761 non-null int64
# has_repair_started                       631761 non-null float64
# vdcmun_id                                631761 non-null int64
# area_assesed_Both                        631761 non-null uint8
# area_assesed_Building removed            631761 non-null uint8
# ...

# %%
#split data into test data
X_test=All_data1[631761:]

# %%
b=pd.DataFrame(b)

# %%
c1=b.iloc[631761:,:]

# %%
c1
# Out:
#          building_id
# 0         a3380c4f75
# 1         a338a4e653
# 2         a338a4e6b7
# 3         a33a6eaa3a
# 4         a33b073ff6
# 5        6604e4896c6
# 6         a33b07430f
# 7         a33c386cf3
# 8         a33c386ee7
# 9         a33c38700f
# 10        a33c387079
# 11       6627e911d56
# 12        a3730e8420
# 13        a373a71a3d
# 14        a3743fb055
# 15        a3743fb121
# 16        a374d84676
# 17        a374d848cb
# 18        a374d8492a
# 19        a37570ddbe
# 20        a376097504
# 21        a3760975cd
# 22        a3aea94dbf
# 23        a376a209ee
# 24        a376a20b1e
# 25        a376a20b83
# 26        a3773aa0da
# 27        a3b1a441bd
# 28        a3773aa19c
# 29        a3773aa2ca
# ...              ...
# 421145   355cf98de6a
# 421146   355cf98df96
# 421147   355cf98e1ef
# 421148   355cf98e2ba
# 421149   355cf98e321
# 421150  215a1bf8eac6
# 421151   355cf98e4af
# 421152  215a1bf8f67f
# 421153   355cf98e63d
# 421154   355cf98e6a3
# 421155   355cf98e705
# ...

# %%
c1=pd.DataFrame(c1)

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 421175 entries, 0 to 421174
# Data columns (total 16 columns):
# district_id                              421175 non-null int64
# has_geotechnical_risk                    421175 non-null float64
# has_geotechnical_risk_fault_crack        421175 non-null int64
# has_geotechnical_risk_flood              421175 non-null int64
# has_geotechnical_risk_land_settlement    421175 non-null int64
# has_geotechnical_risk_landslide          421175 non-null int64
# has_geotechnical_risk_liquefaction       421175 non-null int64
# has_geotechnical_risk_other              421175 non-null int64
# has_geotechnical_risk_rock_fall          421175 non-null int64
# has_repair_started                       421175 non-null float64
# vdcmun_id                                421175 non-null int64
# area_assesed_Both                        421175 non-null uint8
# area_assesed_Building removed            421175 non-null uint8
# ...

# %% [markdown]
# # DecisionTreeClassifier

# %%
 from sklearn.tree import DecisionTreeRegressor
regressor1=DecisionTreeRegressor(random_state=42)
regressor1.fit(X_train,A)
regressor1.score(X_train,A)
# Out:
# 0.742805972351651

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor,BaggingClassifier,AdaBoostClassifier,VotingClassifier,RandomForestClassifier
reeg=RandomForestRegressor(n_estimators=20,random_state=0)
reeg.fit(X_train,A)
reeg.score(X_train,A)
# Out:
# 0.7416720398189754

# %% [markdown]
# # BaggingClassifier

# %%
bg=BaggingClassifier(DecisionTreeClassifier(),max_samples=0.5,max_features=1.0,n_estimators=20)
bg.fit(X_train,A)
bg.score(X_train,A)
# Out:
# 0.6803886279779854

# %% [markdown]
# # AdaBoostClassifier

# %%
Adg=AdaBoostClassifier(DecisionTreeClassifier(),n_estimators=10,learning_rate=1)
Adg.fit(X_train,A) 
Adg.score(X_train,A)
# Out:
# 0.6818559550209652

# %% [markdown]
# # VotingClassifier

# %%
dt=DecisionTreeClassifier()
re=RandomForestClassifier(n_estimators=20,random_state=0)
evc=VotingClassifier(estimators=[('re',re),('dt',dt)],voting='hard')
evc.fit(X_train,A)
evc.score(X_train,A)
# Out:
# /home/sunil/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 0.6818765324228624

# %%
building_structure=pd.read_csv('/home/sunil/Downloads/hacker earth compition/Dataset/Building_Structure.csv')

# %%
building_ownership=pd.read_csv('/home/sunil/Downloads/hacker earth compition/Dataset/Building_Ownership_Use.csv')

# %%
result = pd.merge(building_structure, building_ownership, on='building_id')
res_train=pd.merge(dataset_train,result,on="building_id")
res_test=pd.merge(dataset_train,result,on="building_id")

# %%
res_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 631761 entries, 0 to 631760
# Data columns (total 57 columns):
# area_assesed                              631761 non-null object
# building_id                               631761 non-null object
# district_id                               631761 non-null int64
# has_geotechnical_risk                     631761 non-null float64
# has_geotechnical_risk_fault_crack         631761 non-null int64
# has_geotechnical_risk_flood               631761 non-null int64
# has_geotechnical_risk_land_settlement     631761 non-null int64
# has_geotechnical_risk_landslide           631761 non-null int64
# has_geotechnical_risk_liquefaction        631761 non-null int64
# has_geotechnical_risk_other               631761 non-null int64
# has_geotechnical_risk_rock_fall           631761 non-null int64
# has_repair_started                        598344 non-null float64
# vdcmun_id                                 631761 non-null int64
# ...

# %%
res_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 631761 entries, 0 to 631760
# Data columns (total 57 columns):
# area_assesed                              631761 non-null object
# building_id                               631761 non-null object
# district_id                               631761 non-null int64
# has_geotechnical_risk                     631761 non-null float64
# has_geotechnical_risk_fault_crack         631761 non-null int64
# has_geotechnical_risk_flood               631761 non-null int64
# has_geotechnical_risk_land_settlement     631761 non-null int64
# has_geotechnical_risk_landslide           631761 non-null int64
# has_geotechnical_risk_liquefaction        631761 non-null int64
# has_geotechnical_risk_other               631761 non-null int64
# has_geotechnical_risk_rock_fall           631761 non-null int64
# has_repair_started                        598344 non-null float64
# vdcmun_id                                 631761 non-null int64
# ...

# %% [markdown]
# # predict of DecisionTreeClass

# %%
y_pred=regressor1.predict(X_test)
y_pred=pd.DataFrame(y_pred)
y_pred=np.round(y_pred)
pd.DataFrame(y_pred)
# Out:
#           0
# 0       2.0
# 1       2.0
# 2       4.0
# 3       2.0
# 4       4.0
# 5       3.0
# 6       2.0
# 7       4.0
# 8       2.0
# 9       2.0
# 10      2.0
# 11      2.0
# 12      2.0
# 13      2.0
# 14      2.0
# 15      2.0
# 16      2.0
# 17      2.0
# 18      2.0
# 19      2.0
# 20      2.0
# 21      2.0
# 22      2.0
# 23      2.0
# 24      4.0
# 25      2.0
# 26      2.0
# 27      4.0
# 28      2.0
# 29      2.0
# ...     ...
# 421145  4.0
# 421146  4.0
# 421147  4.0
# 421148  4.0
# 421149  4.0
# 421150  4.0
# 421151  4.0
# 421152  4.0
# 421153  4.0
# 421154  4.0
# 421155  4.0
# 421156  4.0
# 421157  4.0
# 421158  3.0
# 421159  4.0
# 421160  4.0
# 421161  4.0
# 421162  4.0
# 421163  4.0
# 421164  4.0
# 421165  0.0
# 421166  4.0
# 421167  4.0
# 421168  4.0
# 421169  4.0
# 421170  4.0
# 421171  4.0
# 421172  0.0
# 421173  4.0
# 421174  4.0
#
# [421175 rows x 1 columns]

# %%
y_pred.info()
y_pred[0].value_counts()
y_pred=y_pred.rename(columns={0:'damage_grade'})
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421175 entries, 0 to 421174
# Data columns (total 1 columns):
# 0    421175 non-null float64
# dtypes: float64(1)
# memory usage: 3.2 MB

# %%
y_pred.damage_grade.replace([0.0,1.0,2.0,3.0,4.0], ['Grade 1','Grade 2','Grade 3','Grade 4','Grade 5'], inplace=True)
y_pred.head()
file=pd.concat([c1,y_pred],axis=1)

# %%
null_columns=y_pred.columns[y_pred.isnull().any()]
y_pred[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
file=pd.DataFrame(file)

# %%
file.to_csv('122.csv',index=False)

# %%
#prediction = pd.DataFrame(file.to_csv('hacker_earth prediction14.csv',index=False) )

# %%
null_columns=y_pred.columns[y_pred.isnull().any()]
y_pred[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
file
# Out:
#          building_id damage_grade
# 0         a3380c4f75      Grade 3
# 1         a338a4e653      Grade 3
# 2         a338a4e6b7      Grade 5
# 3         a33a6eaa3a      Grade 3
# 4         a33b073ff6      Grade 5
# 5        6604e4896c6      Grade 4
# 6         a33b07430f      Grade 3
# 7         a33c386cf3      Grade 5
# 8         a33c386ee7      Grade 3
# 9         a33c38700f      Grade 3
# 10        a33c387079      Grade 3
# 11       6627e911d56      Grade 3
# 12        a3730e8420      Grade 3
# 13        a373a71a3d      Grade 3
# 14        a3743fb055      Grade 3
# 15        a3743fb121      Grade 3
# 16        a374d84676      Grade 3
# 17        a374d848cb      Grade 3
# 18        a374d8492a      Grade 3
# 19        a37570ddbe      Grade 3
# 20        a376097504      Grade 3
# 21        a3760975cd      Grade 3
# 22        a3aea94dbf      Grade 3
# 23        a376a209ee      Grade 3
# 24        a376a20b1e      Grade 5
# 25        a376a20b83      Grade 3
# ...
